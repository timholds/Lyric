# %%
import pandas as pd
import nltk

#nltk.download('cmudict')
arpabet = nltk.corpus.cmudict.dict()

# %%
def phoneme_dict(key):
    phon_dict = {
    'AA':'vowel',
    'AA0':'vowel',
    'AA1':'vowel',
    'AA2':'vowel',
    'AE':'vowel',
    'AE0':'vowel',
    'AE1':'vowel',
    'AE2':'vowel',
    'AH':'vowel',
    'AH0':'vowel',
    'AH1':'vowel',
    'AH2':'vowel',
    'AO':'vowel',
    'AO0':'vowel',
    'AO1':'vowel',
    'AO2':'vowel',
    'AW':'vowel',
    'AW0':'vowel',
    'AW1':'vowel',
    'AW2':'vowel',
    'AY':'vowel',
    'AY0':'vowel',
    'AY1':'vowel',
    'AY2':'vowel',
    'B':'stop',
    'CH':'affricate',
    'D':'stop',
    'DH':'fricative',
    'EH':'vowel',
    'EH0':'vowel',
    'EH1':'vowel',
    'EH2':'vowel',
    'ER':'vowel',
    'ER0':'vowel',
    'ER1':'vowel',
    'ER2':'vowel',
    'EY':'vowel',
    'EY0':'vowel',
    'EY1':'vowel',
    'EY2':'vowel',
    'F':'fricative',
    'G':'stop',
    'HH':'aspirate',
    'IH':'vowel',
    'IH0':'vowel',
    'IH1':'vowel',
    'IH2':'vowel',
    'IY':'vowel',
    'IY0':'vowel',
    'IY1':'vowel',
    'IY2':'vowel',
    'JH':'affricate',
    'K':'stop',
    'L':'liquid',
    'M':'nasal',
    'N':'nasal',
    'NG':'nasal',
    'OW':'vowel',
    'OW0':'vowel',
    'OW1':'vowel',
    'OW2':'vowel',
    'OY':'vowel',
    'OY0':'vowel',
    'OY1':'vowel',
    'OY2':'vowel',
    'P':'stop',
    'R':'liquid',
    'S':'fricative',
    'SH':'fricative',
    'T': 'stop',
    'TH':'fricative',
    'UH':'vowel',
    'UH0':'vowel',
    'UH1':'vowel',
    'UH2':'vowel',
    'UW':'vowel',
    'UW0':'vowel',
    'UW1':'vowel',
    'UW2':'vowel',
    'V':'fricative',
    'W' : 'semivowel',
    'Y':'semivowel',
    'Z':'fricative',
    'ZH':'fricative',
    }
    
    return phon_dict[key]

phoneme_dict('Y')
# Out:
# 'semivowel'

# %%
def txt_to_phonemes(file):
    phoneme_types = []
    error = 0
    
    with open(file, 'r') as f:
        file_content = f.read()
        
        tokens = nltk.word_tokenize(file_content)
        
        for word in tokens:
            word = word.lower()
            try:
                phonemes = arpabet[word][0]
                print(phonemes)
                for p in phonemes:
                    sound = phoneme_dict(p)
                    print(sound)
                    phoneme_types.append(sound)
            except Exception as e:
                print("Error " + str(e))
                error += 1
       
        print('Error is ' + str(error))
        return phoneme_types
       

txt_to_phonemes('Radioactive-Introduction_Yelawolf.txt')
#phonemes
# Out:
# Error '['
# ['R', 'OW1', 'B', 'AA2', 'T']
# liquid
# vowel
# stop
# vowel
# stop
# Error ']'
# ['DH', 'AH0']
# fricative
# vowel
# ['Y', 'UW0', 'N', 'AY1', 'T', 'AH0', 'D']
# semivowel
# vowel
# nasal
# vowel
# stop
# vowel
# stop
# ['S', 'T', 'EY1', 'T', 'S']
# fricative
# stop
# vowel
# stop
# fricative
# ['AA1', 'R', 'M', 'IY0']
# vowel
# liquid
# nasal
# vowel
# ['HH', 'AE1', 'Z']
# aspirate
# vowel
# fricative
# ['IH1', 'SH', 'UW0', 'D']
# vowel
# fricative
# vowel
# stop
# ['AH0']
# vowel
# ['W', 'AO1', 'R', 'N', 'IH0', 'NG']
# semivowel
# vowel
# liquid
# nasal
# vowel
# nasal
# ['TH', 'R', 'IY1']
# fricative
# liquid
# vowel
# ['N', 'UW1', 'K', 'L', 'IY0', 'ER0']
# nasal
# vowel
# stop
# liquid
# vowel
# vowel
# ['B', 'AA1', 'M', 'Z']
# stop
# vowel
# nasal
# fricative
# ['HH', 'AE1', 'V']
# aspirate
# vowel
# fricative
# ['B', 'IH1', 'N']
# stop
# vowel
# nasal
# ['L', 'AO1', 'N', 'CH', 'T']
# liquid
# vowel
# nasal
# affricate
# stop
# ['F', 'R', 'AH1', 'M']
# fricative
# liquid
# vowel
# nasal
# ['N', 'AO1', 'R', 'TH']
# nasal
# vowel
# liquid
# fricative
# ['K', 'AO0', 'R', 'IY1', 'AH0']
# stop
# vowel
# liquid
# vowel
# vowel
# ['AH0', 'N', 'D']
# vowel
# nasal
# stop
# ['W', 'IH1', 'L']
# semivowel
# vowel
# liquid
# ['HH', 'IH1', 'T']
# aspirate
# vowel
# stop
# ['AO0', 'R', 'L', 'AE1', 'N', 'D', 'OW0']
# vowel
# liquid
# liquid
# vowel
# nasal
# stop
# vowel
# Error ','
# ['F', 'L', 'AO1', 'R', 'AH0', 'D', 'AH0']
# fricative
# liquid
# vowel
# liquid
# vowel
# stop
# vowel
# Error ';'
# ['L', 'AA1', 'S']
# liquid
# vowel
# fricative
# ['V', 'EY1', 'G', 'AH0', 'S']
# fricative
# vowel
# stop
# vowel
# fricative
# Error ','
# ['N', 'AH0', 'V', 'AA1', 'D', 'AH0']
# nasal
# vowel
# fricative
# vowel
# stop
# vowel
# Error ';'
# ['AH0', 'N', 'D']
# vowel
# nasal
# stop
# ['N', 'UW1']
# nasal
# vowel
# ['Y', 'AO1', 'R', 'K']
# semivowel
# vowel
# liquid
# stop
# ['S', 'IH1', 'T', 'IY0']
# fricative
# vowel
# stop
# vowel
# Error ','
# ['N', 'UW1']
# nasal
# vowel
# ['Y', 'AO1', 'R', 'K']
# semivowel
# vowel
# liquid
# stop
# ['DH', 'IH1', 'S']
# fricative
# vowel
# fricative
# ['W', 'IH1', 'L']
# semivowel
# vowel
# liquid
# ['IH0', 'K', 'S', 'P', 'AY1', 'R']
# vowel
# stop
# fricative
# stop
# vowel
# liquid
# ['AE1', 'T']
# vowel
# stop
# Error '5'
# ['AH0', 'K', 'L', 'AA1', 'K']
# vowel
# stop
# liquid
# vowel
# stop
# ['AE1', 'M']
# vowel
# nasal
# ['IY1', 'S', 'T', 'ER0', 'N']
# vowel
# fricative
# stop
# vowel
# nasal
# ['S', 'T', 'AE1', 'N', 'D', 'ER0', 'D']
# fricative
# stop
# vowel
# nasal
# stop
# vowel
# stop
# ['T', 'AY1', 'M']
# stop
# vowel
# nasal
# ['P', 'L', 'IY1', 'Z']
# stop
# liquid
# vowel
# fricative
# ['G', 'EH1', 'T']
# stop
# vowel
# stop
# ['T', 'UW1']
# stop
# vowel
# ['AE1', 'N']
# vowel
# nasal
# ['AH1', 'N', 'D', 'ER0', 'G', 'R', 'AW2', 'N', 'D']
# vowel
# nasal
# stop
# vowel
# stop
# liquid
# vowel
# nasal
# stop
# ['SH', 'EH1', 'L', 'T', 'ER0']
# fricative
# vowel
# liquid
# stop
# vowel
# ['AO1', 'R']
# vowel
# liquid
# ['AH0']
# vowel
# ['F', 'AO1', 'L', 'AW2', 'T']
# fricative
# vowel
# liquid
# vowel
# stop
# ['SH', 'EH1', 'L', 'T', 'ER0']
# fricative
# vowel
# liquid
# stop
# vowel
# ['IH0', 'M', 'IY1', 'D', 'IY0', 'AH0', 'T', 'L', 'IY0']
# vowel
# nasal
# vowel
# stop
# vowel
# vowel
# stop
# liquid
# vowel
# ['W', 'AH1', 'N', 'S']
# semivowel
# vowel
# nasal
# fricative
# ['AH0', 'G', 'EH1', 'N']
# vowel
# stop
# vowel
# nasal
# Error ','
# ['TH', 'R', 'IY1']
# fricative
# liquid
# vowel
# ['N', 'UW1', 'K', 'L', 'IY0', 'ER0']
# nasal
# vowel
# stop
# liquid
# vowel
# vowel
# ['B', 'AA1', 'M', 'Z']
# stop
# vowel
# nasal
# fricative
# ['HH', 'AE1', 'V']
# aspirate
# vowel
# fricative
# ['B', 'IH1', 'N']
# stop
# vowel
# nasal
# ['L', 'AO1', 'N', 'CH', 'T']
# liquid
# vowel
# nasal
# affricate
# stop
# ['F', 'R', 'AH1', 'M']
# fricative
# liquid
# vowel
# nasal
# ['N', 'AO1', 'R', 'TH']
# nasal
# vowel
# liquid
# fricative
# ['K', 'AO0', 'R', 'IY1', 'AH0']
# stop
# vowel
# liquid
# vowel
# vowel
# ['AH0', 'N', 'D']
# vowel
# nasal
# stop
# ['W', 'IH1', 'L']
# semivowel
# vowel
# liquid
# ['HH', 'IH1', 'T']
# aspirate
# vowel
# stop
# ['AO0', 'R', 'L', 'AE1', 'N', 'D', 'OW0']
# vowel
# liquid
# liquid
# vowel
# nasal
# stop
# vowel
# Error ','
# ['F', 'L', 'AO1', 'R', 'AH0', 'D', 'AH0']
# fricative
# liquid
# vowel
# liquid
# vowel
# stop
# vowel
# Error ';'
# ['L', 'AA1', 'S']
# liquid
# vowel
# fricative
# ['V', 'EY1', 'G', 'AH0', 'S']
# fricative
# vowel
# stop
# vowel
# fricative
# Error ','
# ['N', 'AH0', 'V', 'AA1', 'D', 'AH0']
# nasal
# vowel
# fricative
# vowel
# stop
# vowel
# Error ';'
# ['AH0', 'N', 'D']
# vowel
# nasal
# stop
# ['N', 'UW1']
# nasal
# vowel
# ['Y', 'AO1', 'R', 'K']
# semivowel
# vowel
# liquid
# stop
# ['S', 'IH1', 'T', 'IY0']
# fricative
# vowel
# stop
# vowel
# Error ','
# ['N', 'UW1']
# nasal
# vowel
# ['Y', 'AO1', 'R', 'K']
# semivowel
# vowel
# liquid
# stop
# ['DH', 'IH1', 'S']
# fricative
# vowel
# fricative
# ['W', 'AO1', 'R', 'N', 'IH0', 'NG']
# semivowel
# vowel
# liquid
# nasal
# vowel
# nasal
# ['W', 'IH1', 'L']
# semivowel
# vowel
# liquid
# ['IH0', 'K', 'S', 'P', 'AY1', 'R']
# vowel
# stop
# fricative
# stop
# vowel
# liquid
# ['AE1', 'T']
# vowel
# stop
# Error '5'
# ['AH0', 'K', 'L', 'AA1', 'K']
# vowel
# stop
# liquid
# vowel
# stop
# ['AE1', 'M']
# vowel
# nasal
# ['IY1', 'S', 'T', 'ER0', 'N']
# vowel
# fricative
# stop
# vowel
# nasal
# ['S', 'T', 'AE1', 'N', 'D', 'ER0', 'D']
# fricative
# stop
# vowel
# nasal
# stop
# vowel
# stop
# ['T', 'AY1', 'M']
# stop
# vowel
# nasal
# Error '['
# Error 'yelawolf'
# Error ']'
# ['AY1']
# vowel
# ['AE1', 'M']
# vowel
# nasal
# Error '...'
# ['AY1']
# vowel
# ['AE1', 'M']
# vowel
# nasal
# ['DH', 'AH0']
# fricative
# vowel
# ['AH0', 'M', 'EH1', 'R', 'AH0', 'K', 'AH0', 'N']
# vowel
# nasal
# vowel
# liquid
# vowel
# stop
# vowel
# nasal
# ['IY1', 'G', 'AH0', 'L']
# vowel
# stop
# vowel
# liquid
# Error ','
# ['AY1', 'Z']
# vowel
# fricative
# ['AH1', 'V']
# vowel
# fricative
# ['AH0']
# vowel
# ['S', 'P', 'EH1', 'R', 'OW0']
# fricative
# stop
# vowel
# liquid
# vowel
# ['R', 'AY1', 'T']
# liquid
# vowel
# stop
# ['HH', 'AE1', 'N', 'D']
# aspirate
# vowel
# nasal
# stop
# ['B', 'R', 'AE1', 'N', 'CH']
# stop
# liquid
# vowel
# nasal
# affricate
# Error ','
# ['L', 'EH1', 'F', 'T']
# liquid
# vowel
# fricative
# stop
# ['HH', 'AE1', 'N', 'D']
# aspirate
# vowel
# nasal
# stop
# ['AE1', 'R', 'OW0']
# vowel
# liquid
# vowel
# ['CH', 'AE1', 'S', 'IH0', 'N']
# affricate
# vowel
# fricative
# vowel
# nasal
# Error "'"
# ['AH0']
# vowel
# ['D', 'AA1', 'L', 'ER0']
# stop
# vowel
# liquid
# vowel
# Error ','
# ['IH0', 'N']
# vowel
# nasal
# ['AE1', 'N']
# vowel
# nasal
# ['IH0', 'M', 'P', 'AA1', 'L', 'AH0']
# vowel
# nasal
# stop
# vowel
# liquid
# vowel
# ['W', 'AY1', 'T']
# semivowel
# vowel
# stop
# ['T', 'R', 'AE1', 'SH']
# stop
# liquid
# vowel
# fricative
# ['HH', 'AA1', 'R', 'T']
# aspirate
# vowel
# liquid
# stop
# ['TH', 'R', 'AA1', 'B']
# fricative
# liquid
# vowel
# stop
# Error ','
# ['M', 'EH1', 'L', 'OW0']
# nasal
# vowel
# liquid
# vowel
# ['Y', 'EH1', 'L', 'OW0']
# semivowel
# vowel
# liquid
# vowel
# Error 'drinkin'
# Error "'"
# ['HH', 'AA1', 'R', 'D']
# aspirate
# vowel
# liquid
# stop
# ['L', 'IH1', 'K', 'ER0']
# liquid
# vowel
# stop
# vowel
# Error ','
# Error 'brauds'
# ['G', 'EH1', 'T']
# stop
# vowel
# stop
# ['AA1', 'N']
# vowel
# nasal
# ['M', 'AY1']
# nasal
# vowel
# ['L', 'EH1', 'V', 'AH0', 'L']
# liquid
# vowel
# fricative
# vowel
# liquid
# ['AY1']
# vowel
# ['AH0', 'M']
# vowel
# nasal
# ['HH', 'AA1', 'T', 'ER0']
# aspirate
# vowel
# stop
# vowel
# ['DH', 'AE1', 'N']
# fricative
# vowel
# nasal
# ['DH', 'AH0']
# fricative
# vowel
# ['B', 'AA1', 'T', 'AH0', 'M']
# stop
# vowel
# stop
# vowel
# nasal
# ['S', 'AY1', 'D']
# fricative
# vowel
# stop
# ['AH1', 'V']
# vowel
# fricative
# ['AH0']
# vowel
# Error 'whistlin'
# Error "'"
# ['K', 'EH1', 'T', 'AH0', 'L']
# stop
# vowel
# stop
# vowel
# liquid
# ['DH', 'EY1']
# fricative
# vowel
# ['TH', 'R', 'UW1']
# fricative
# liquid
# vowel
# ['AH0']
# vowel
# ['M', 'AW1', 'N', 'T', 'AH0', 'N']
# nasal
# vowel
# nasal
# stop
# vowel
# nasal
# ['AE1', 'T']
# vowel
# stop
# ['M', 'IY1']
# nasal
# vowel
# Error ','
# ['AY1']
# vowel
# ['G', 'AA1', 'T']
# stop
# vowel
# stop
# ['HH', 'IH1', 'T']
# aspirate
# vowel
# stop
# ['W', 'IH1', 'DH']
# semivowel
# vowel
# fricative
# ['AH0']
# vowel
# ['P', 'EH1', 'B', 'AH0', 'L']
# stop
# vowel
# stop
# vowel
# liquid
# ['DH', 'EY1']
# fricative
# vowel
# ['S', 'EH1', 'N', 'T']
# fricative
# vowel
# nasal
# stop
# ['M', 'IY1']
# nasal
# vowel
# ['T', 'UW1']
# stop
# vowel
# ['HH', 'EH1', 'L']
# aspirate
# vowel
# liquid
# Error ','
# ['AH0', 'N', 'D']
# vowel
# nasal
# stop
# ['AY1']
# vowel
# ['SH', 'IH1', 'T']
# fricative
# vowel
# stop
# ['AA1', 'N']
# vowel
# nasal
# ['DH', 'AH0']
# fricative
# vowel
# ['D', 'EH1', 'V', 'AH0', 'L']
# stop
# vowel
# fricative
# vowel
# liquid
# ['T', 'R', 'AY1']
# stop
# liquid
# vowel
# ['T', 'UW1']
# stop
# vowel
# ['B', 'EH1', 'R', 'IY0']
# stop
# vowel
# liquid
# vowel
# ['M', 'AY1']
# nasal
# vowel
# ['CH', 'EH1', 'V', 'IY0']
# affricate
# vowel
# fricative
# vowel
# ['B', 'AA1', 'K', 'S']
# stop
# vowel
# stop
# fricative
# ['B', 'AH1', 'T']
# stop
# vowel
# stop
# ['AY1']
# vowel
# ['W', 'OW1']
# semivowel
# vowel
# Error "n't"
# ['B', 'AH1', 'K', 'AH0', 'L']
# stop
# vowel
# stop
# vowel
# liquid
# ['AH0', 'N', 'D']
# vowel
# nasal
# stop
# ['DH', 'AE1', 'T']
# fricative
# vowel
# stop
# ['EH1', 'S']
# vowel
# fricative
# ['AH0']
# vowel
# ['D', 'IY1', 'P']
# stop
# vowel
# stop
# ['HH', 'OW1', 'L']
# aspirate
# vowel
# liquid
# ['B', 'IH1', 'CH']
# stop
# vowel
# affricate
# Error ','
# ['B', 'R', 'IH1', 'NG']
# stop
# liquid
# vowel
# nasal
# ['AH0']
# vowel
# ['L', 'AO1', 'NG']
# liquid
# vowel
# nasal
# ['SH', 'AH1', 'V', 'AH0', 'L']
# fricative
# vowel
# fricative
# vowel
# liquid
# ['L', 'AO1', 'NG']
# liquid
# vowel
# nasal
# ['G', 'AO1', 'N']
# stop
# vowel
# nasal
# Error ','
# ['AY1']
# vowel
# ['AH0', 'M']
# vowel
# nasal
# ['G', 'R', 'OW1', 'N']
# stop
# liquid
# vowel
# nasal
# ['AH1', 'P']
# vowel
# stop
# Error ','
# ['AH0', 'N', 'D']
# vowel
# nasal
# stop
# ['AY1']
# vowel
# ['AH0', 'M']
# vowel
# nasal
# ['G', 'AO1', 'N']
# stop
# vowel
# nasal
# ['K', 'AH1', 'T']
# stop
# vowel
# stop
# ['Y', 'UW1']
# semivowel
# vowel
# ['B', 'AH1', 'T']
# stop
# vowel
# stop
# ['AH0']
# vowel
# ['G', 'R', 'OW1', 'N']
# stop
# liquid
# vowel
# nasal
# ['L', 'EY1', 'D', 'IY0']
# liquid
# vowel
# stop
# vowel
# Error ','
# ['B', 'AH1', 'T']
# stop
# vowel
# stop
# ['IH1', 'F']
# vowel
# fricative
# ['Y', 'UW1']
# semivowel
# vowel
# ['W', 'AA1', 'N', 'T']
# semivowel
# vowel
# nasal
# stop
# ['AH0']
# vowel
# ['B', 'L', 'EY1', 'D']
# stop
# liquid
# vowel
# stop
# Error ','
# ['DH', 'EH1', 'N']
# fricative
# vowel
# nasal
# ['HH', 'OW1', 'M', 'Z']
# aspirate
# vowel
# nasal
# fricative
# ['F', 'AH1', 'K']
# fricative
# vowel
# stop
# ['Y', 'UW1']
# semivowel
# vowel
# ['F', 'AH1', 'K']
# fricative
# vowel
# stop
# ['Y', 'UW1']
# semivowel
# vowel
# ['T', 'IH1', 'L']
# stop
# vowel
# liquid
# ['Y', 'UW1']
# semivowel
# vowel
# ['K', 'AH1']
# stop
# vowel
# Error "n't"
# ['T', 'EY1', 'K']
# stop
# vowel
# stop
# ['AH0']
# vowel
# ['SH', 'IH1', 'T']
# fricative
# vowel
# stop
# ['Y', 'AE1']
# semivowel
# vowel
# ['AY1']
# vowel
# ['AH0', 'M']
# vowel
# nasal
# ['AH0']
# vowel
# ['F', 'AH1', 'K']
# fricative
# vowel
# stop
# ['EH1', 'V', 'R', 'IY0', 'B', 'AA2', 'D', 'IY0']
# vowel
# fricative
# liquid
# vowel
# stop
# vowel
# stop
# vowel
# Error ','
# ['T', 'S', 'UW0', 'N', 'AA1', 'M', 'IY0']
# stop
# fricative
# vowel
# nasal
# vowel
# nasal
# vowel
# Error ','
# ['B', 'EH1', 'T', 'ER0']
# stop
# vowel
# stop
# vowel
# ['AE1', 'NG', 'K', 'ER0']
# vowel
# nasal
# stop
# vowel
# ['DH', 'AH0']
# fricative
# vowel
# ['SH', 'IH1', 'P']
# fricative
# vowel
# stop
# ['EY1', 'M']
# vowel
# nasal
# ['F', 'AO1', 'R']
# fricative
# vowel
# liquid
# ['DH', 'AH0']
# fricative
# vowel
# ['AE1', 'NG', 'K', 'AH0', 'L', 'Z']
# vowel
# nasal
# stop
# vowel
# liquid
# fricative
# ['AH0', 'N', 'D']
# vowel
# nasal
# stop
# ['R', 'IH1', 'S', 'T']
# liquid
# vowel
# fricative
# stop
# Error ','
# ['AY1']
# vowel
# ['K', 'EY1', 'M']
# stop
# vowel
# nasal
# ['F', 'AO1', 'R']
# fricative
# vowel
# liquid
# ['DH', 'AH0']
# fricative
# vowel
# ['D', 'EY1', 'N', 'JH', 'ER0', 'AH0', 'S']
# stop
# vowel
# nasal
# affricate
# vowel
# vowel
# fricative
# ['SH', 'IH1', 'T']
# fricative
# vowel
# stop
# ['AY1']
# vowel
# ['K', 'L', 'EY1', 'M', 'D']
# stop
# liquid
# vowel
# nasal
# stop
# ['T', 'UW1']
# stop
# vowel
# ['B', 'IY1']
# stop
# vowel
# ['N', 'EY1', 'M', 'D']
# nasal
# vowel
# nasal
# stop
# ['F', 'AO1', 'R']
# fricative
# vowel
# liquid
# ['DH', 'AH0']
# fricative
# vowel
# ['HH', 'IH1', 'T', 'S']
# aspirate
# vowel
# stop
# fricative
# Error ','
# ['DH', 'AH0']
# fricative
# vowel
# ['G', 'EY1', 'M']
# stop
# vowel
# nasal
# ['IH1', 'Z']
# vowel
# fricative
# ['AH0']
# vowel
# ['CH', 'EY1', 'N']
# affricate
# vowel
# nasal
# ['DH', 'AE1', 'T']
# fricative
# vowel
# stop
# ['AY1']
# vowel
# ['G', 'R', 'IH1', 'P']
# stop
# liquid
# vowel
# stop
# ['S', 'L', 'AE1', 'NG']
# fricative
# liquid
# vowel
# nasal
# ['F', 'R', 'AH1', 'M']
# fricative
# liquid
# vowel
# nasal
# ['DH', 'AH0']
# fricative
# vowel
# ['P', 'EY1', 'N']
# stop
# vowel
# nasal
# ['AH1', 'V']
# vowel
# fricative
# ['AH0']
# vowel
# ['T', 'R', 'IH1', 'P']
# stop
# liquid
# vowel
# stop
# ['IH1', 'T']
# vowel
# stop
# ['T', 'UH1', 'K']
# stop
# vowel
# stop
# ['T', 'UW1']
# stop
# vowel
# ['S', 'IY1']
# fricative
# vowel
# ['W', 'EY1', 'N']
# semivowel
# vowel
# nasal
# ['IH0', 'N']
# vowel
# nasal
# ['DH', 'AH0']
# fricative
# vowel
# ['W', 'IH1', 'P']
# semivowel
# vowel
# stop
# ['AY1']
# vowel
# ['B', 'IH0', 'K', 'EY1', 'M']
# stop
# vowel
# stop
# vowel
# nasal
# ['W', 'AH1', 'T']
# semivowel
# vowel
# stop
# ['AY1']
# vowel
# ['K', 'EY1', 'M']
# stop
# vowel
# nasal
# ['T', 'UW1']
# stop
# vowel
# ['G', 'EH1', 'T']
# stop
# vowel
# stop
# ['DH', 'AH0']
# fricative
# vowel
# ['CH', 'EY1', 'N', 'Z']
# affricate
# vowel
# nasal
# fricative
# ['F', 'AO1', 'R']
# fricative
# vowel
# liquid
# ['DH', 'AH0']
# fricative
# vowel
# ['CH', 'EY1', 'N', 'JH']
# affricate
# vowel
# nasal
# affricate
# ['AY1']
# vowel
# ['G', 'IH1', 'V']
# stop
# vowel
# fricative
# ['AH0']
# vowel
# ['K', 'W', 'AO1', 'R', 'T', 'ER0']
# stop
# semivowel
# vowel
# liquid
# stop
# vowel
# ['F', 'AO1', 'R']
# fricative
# vowel
# liquid
# ['Y', 'AO1', 'R']
# semivowel
# vowel
# liquid
# ['TH', 'AO1', 'T']
# fricative
# vowel
# stop
# Error ','
# ['AH0', 'P', 'R', 'IY1', 'SH', 'IY0', 'EY2', 'T']
# vowel
# stop
# liquid
# vowel
# fricative
# vowel
# vowel
# stop
# ['DH', 'AH0']
# fricative
# vowel
# ['K', 'AA2', 'N', 'T', 'R', 'AH0', 'B', 'Y', 'UW1', 'SH', 'AH0', 'N']
# stop
# vowel
# nasal
# stop
# liquid
# vowel
# stop
# semivowel
# vowel
# fricative
# vowel
# nasal
# Error 'slumerican'
# Error ','
# ['AY1']
# vowel
# Error "'d"
# ['D', 'IH0', 'P', 'R', 'IY1', 'SH', 'IY0', 'EY2', 'T']
# stop
# vowel
# stop
# liquid
# vowel
# fricative
# vowel
# vowel
# stop
# ['DH', 'AH0']
# fricative
# vowel
# ['K', 'AA2', 'N', 'S', 'T', 'AH0', 'T', 'UW1', 'SH', 'AH0', 'N']
# stop
# vowel
# nasal
# fricative
# stop
# vowel
# stop
# vowel
# fricative
# vowel
# nasal
# ['AH0', 'L', 'IY1', 'V', 'IY0', 'EY2', 'T']
# vowel
# liquid
# vowel
# fricative
# vowel
# vowel
# stop
# ['DH', 'AH0']
# fricative
# vowel
# ['K', 'R', 'UW1']
# stop
# liquid
# vowel
# ['W', 'EH1', 'N']
# semivowel
# vowel
# nasal
# Error ','
# ['AY1']
# vowel
# ['L', 'IY1', 'V']
# liquid
# vowel
# fricative
# ['AH0']
# vowel
# ['P', 'EY1', 'JH']
# stop
# vowel
# affricate
# ['IH0', 'N']
# vowel
# nasal
# ['R', 'UW1', 'AH0', 'N', 'Z']
# liquid
# vowel
# vowel
# nasal
# fricative
# ['T', 'UW1']
# stop
# vowel
# ['IY1', 'CH']
# vowel
# affricate
# ['HH', 'IH1', 'Z']
# aspirate
# vowel
# fricative
# ['OW1', 'N']
# vowel
# nasal
# Error ','
# ['AY1']
# vowel
# ['G', 'EH1', 'S']
# stop
# vowel
# fricative
# ['AY1']
# vowel
# ['OW1', 'N']
# vowel
# nasal
# ['IY1', 'CH']
# vowel
# affricate
# ['AH0', 'N', 'D']
# vowel
# nasal
# stop
# ['EH1', 'V', 'ER0', 'IY0']
# vowel
# fricative
# vowel
# vowel
# ['R', 'UW1', 'M']
# liquid
# vowel
# nasal
# ['IH0', 'N']
# vowel
# nasal
# ['DH', 'AH0']
# fricative
# vowel
# ['HH', 'AW1', 'S']
# aspirate
# vowel
# fricative
# ['AY1']
# vowel
# ['B', 'IH1', 'L', 'T']
# stop
# vowel
# liquid
# stop
# ['IH1', 'Z']
# vowel
# fricative
# ['F', 'UH1', 'L']
# fricative
# vowel
# liquid
# ['AH1', 'V']
# vowel
# fricative
# ['HH', 'OW1', 'P', 'S']
# aspirate
# vowel
# stop
# fricative
# Error ','
# ['N', 'OW1']
# nasal
# vowel
# ['IH1', 'F', 'S']
# vowel
# fricative
# fricative
# ['S', 'OW1']
# fricative
# vowel
# ['AY1']
# vowel
# ['S', 'T', 'AE1', 'N', 'D']
# fricative
# stop
# vowel
# nasal
# stop
# ['W', 'IH1', 'DH']
# semivowel
# vowel
# fricative
# ['AH0']
# vowel
# ['JH', 'AY1', 'AH0', 'N', 'T']
# affricate
# vowel
# vowel
# nasal
# stop
# ['L', 'AY1', 'K']
# liquid
# vowel
# stop
# ['AH0']
# vowel
# ['K', 'IH1', 'NG']
# stop
# vowel
# nasal
# Error ','
# ['N', 'OW1']
# nasal
# vowel
# ['S', 'T', 'IH1', 'L', 'T', 'S']
# fricative
# stop
# vowel
# liquid
# stop
# fricative
# ['IH1', 'F']
# vowel
# fricative
# ['AY1']
# vowel
# ['AH0', 'M']
# vowel
# nasal
# ['JH', 'EH2', 'N', 'ER0', 'EY1', 'SH', 'AH0', 'N']
# affricate
# vowel
# nasal
# vowel
# vowel
# fricative
# vowel
# nasal
# ['EH1', 'K', 'S']
# vowel
# stop
# fricative
# Error ','
# ['AY1']
# vowel
# ['AH0', 'M']
# vowel
# nasal
# ['S', 'EH1', 'L', 'IH0', 'N']
# fricative
# vowel
# liquid
# vowel
# nasal
# Error "'"
# ['EH1', 'K', 'S']
# vowel
# stop
# fricative
# Error ','
# ['N', 'OW1']
# nasal
# vowel
# ['P', 'IH1', 'L', 'Z']
# stop
# vowel
# liquid
# fricative
# Error 'dopeman'
# Error 'choppin'
# Error "'"
# ['AH1', 'P']
# vowel
# stop
# ['L', 'AY1', 'N', 'Z']
# liquid
# vowel
# nasal
# fricative
# ['Y', 'UW1']
# semivowel
# vowel
# ['D', 'UW1']
# stop
# vowel
# Error "n't"
# ['S', 'N', 'IH1', 'F']
# fricative
# nasal
# vowel
# fricative
# ['R', 'EH1', 'D']
# liquid
# vowel
# stop
# ['AH0', 'M']
# vowel
# nasal
# Error ','
# ['AY1']
# vowel
# ['AH0', 'M']
# vowel
# nasal
# Error 'bringin'
# Error "'"
# ['B', 'AE1', 'K']
# stop
# vowel
# stop
# ['B', 'UH1', 'K', 'L', 'AH0', 'T', 'S']
# stop
# vowel
# stop
# liquid
# vowel
# stop
# fricative
# ['AH0', 'N', 'D']
# vowel
# nasal
# stop
# Error 'hookless'
# Error ','
# ['L', 'IH1', 'R', 'IH0', 'K', 'S']
# liquid
# vowel
# liquid
# vowel
# stop
# fricative
# ['S', 'OW1']
# fricative
# vowel
# ['Y', 'UW1']
# semivowel
# vowel
# ['K', 'AE1', 'N']
# stop
# vowel
# nasal
# ['B', 'IY1']
# stop
# vowel
# ['S', 'ER1', 'T', 'AH0', 'N']
# fricative
# vowel
# stop
# vowel
# nasal
# ['JH', 'AH1', 'S', 'T']
# affricate
# vowel
# fricative
# stop
# ['IH0', 'N']
# vowel
# nasal
# ['K', 'EY1', 'S']
# stop
# vowel
# fricative
# ['Y', 'UW1']
# semivowel
# vowel
# ['D', 'IH1', 'D']
# stop
# vowel
# stop
# Error "n't"
# ['HH', 'IY1', 'R']
# aspirate
# vowel
# liquid
# ['IH1', 'T']
# vowel
# stop
# ['B', 'AH1', 'T']
# stop
# vowel
# stop
# ['W', 'AH1', 'T']
# semivowel
# vowel
# stop
# ['HH', 'IY1']
# aspirate
# vowel
# ['S', 'EH1', 'Z']
# fricative
# vowel
# fricative
# Error ','
# ['K', 'AH1', 'M']
# stop
# vowel
# nasal
# ['AH0', 'G', 'EH1', 'N']
# vowel
# stop
# vowel
# nasal
# Error '?'
# ['W', 'AH1', 'T']
# semivowel
# vowel
# stop
# ['IH1', 'Z']
# vowel
# fricative
# ['DH', 'AE1', 'T']
# fricative
# vowel
# stop
# Error '?'
# ['K', 'AH1', 'M']
# stop
# vowel
# nasal
# ['T', 'UW1']
# stop
# vowel
# ['ER1', 'TH']
# vowel
# fricative
# Error ','
# ['T', 'AH1', 'CH', 'D', 'AW2', 'N']
# stop
# vowel
# affricate
# stop
# vowel
# nasal
# Error ','
# ['AY1']
# vowel
# ['M', 'AY1', 'T']
# nasal
# vowel
# stop
# ['B', 'IY1']
# stop
# vowel
# ['Y', 'AO1', 'R']
# semivowel
# vowel
# liquid
# Error 'runnin'
# Error "'"
# ['B', 'AE1', 'K']
# stop
# vowel
# stop
# ['B', 'IH0', 'K', 'AO1', 'Z']
# stop
# vowel
# stop
# vowel
# fricative
# ['Y', 'UW1']
# semivowel
# vowel
# ['HH', 'AA1', 'L', 'ER0', 'D']
# aspirate
# vowel
# liquid
# vowel
# stop
# Error ','
# ['R', 'AH1', 'N']
# liquid
# vowel
# nasal
# ['IH1', 'T']
# vowel
# stop
# ['B', 'AE1', 'K']
# stop
# vowel
# stop
# ['S', 'T', 'EY1']
# fricative
# stop
# vowel
# ['K', 'UW1', 'L']
# stop
# vowel
# liquid
# ['IH0', 'N', 'AH1', 'F']
# vowel
# nasal
# vowel
# fricative
# ['T', 'UW1']
# stop
# vowel
# ['W', 'EH1', 'R']
# semivowel
# vowel
# liquid
# ['T', 'AH0', 'B', 'AA1', 'G', 'AH0', 'N', 'Z']
# stop
# vowel
# stop
# vowel
# stop
# vowel
# nasal
# fricative
# ['AE1', 'Z']
# vowel
# fricative
# ['AH0']
# vowel
# ['S', 'AH1', 'M', 'ER0']
# fricative
# vowel
# nasal
# vowel
# ['HH', 'AE1', 'T']
# aspirate
# vowel
# stop
# ['S', 'T', 'EH1', 'D', 'IY0']
# fricative
# stop
# vowel
# stop
# vowel
# ['AA1', 'N']
# vowel
# nasal
# ['DH', 'AH0']
# fricative
# vowel
# ['D', 'R', 'AH1', 'M']
# stop
# liquid
# vowel
# nasal
# ['AY1']
# vowel
# ['R', 'AE1', 'P']
# liquid
# vowel
# stop
# Error ','
# ['HH', 'OW1', 'P']
# aspirate
# vowel
# stop
# ['DH', 'EH1', 'R']
# fricative
# vowel
# liquid
# ['EH1', 'S']
# vowel
# fricative
# ['N', 'OW1']
# nasal
# vowel
# ['W', 'AH1', 'N']
# semivowel
# vowel
# nasal
# ['AH1', 'N', 'D', 'ER0']
# vowel
# nasal
# stop
# vowel
# ['DH', 'AE1', 'T']
# fricative
# vowel
# stop
# ['R', 'AA1', 'K']
# liquid
# vowel
# stop
# ['DH', 'AE1', 'T']
# fricative
# vowel
# stop
# ['AY1']
# vowel
# ['R', 'OW1', 'L']
# liquid
# vowel
# liquid
# Error ','
# ['M', 'AO1', 'SH']
# nasal
# vowel
# fricative
# ['P', 'IH1', 'T']
# stop
# vowel
# stop
# ['F', 'L', 'OW1']
# fricative
# liquid
# vowel
# ['G', 'ER1', 'L', 'Z']
# stop
# vowel
# liquid
# fricative
# ['AA1', 'N']
# vowel
# nasal
# ['Y', 'AO1', 'R']
# semivowel
# vowel
# liquid
# ['SH', 'OW1', 'L', 'D', 'ER0', 'Z']
# fricative
# vowel
# liquid
# stop
# vowel
# fricative
# ['G', 'EH1', 'T']
# stop
# vowel
# stop
# ['T', 'AA1', 'P', 'L', 'AH0', 'S']
# stop
# vowel
# stop
# liquid
# vowel
# fricative
# ['AE1', 'T']
# vowel
# stop
# ['DH', 'AH0']
# fricative
# vowel
# ['SH', 'OW1', 'Z']
# fricative
# vowel
# fricative
# ['F', 'AH1', 'K']
# fricative
# vowel
# stop
# ['Y', 'AO1', 'R']
# semivowel
# vowel
# liquid
# ['M', 'AA1', 'P']
# nasal
# vowel
# stop
# ['AH0', 'N', 'D']
# vowel
# nasal
# stop
# ['G', 'L', 'OW1']
# stop
# liquid
# vowel
# Error ','
# ['K', 'AH1']
# stop
# vowel
# Error "n't"
# ['M', 'AA1', 'P']
# nasal
# vowel
# stop
# ['AH0']
# vowel
# ['D', 'ER1', 'T']
# stop
# vowel
# stop
# ['R', 'OW1', 'D']
# liquid
# vowel
# stop
# Error ','
# ['IH1', 'T']
# vowel
# stop
# ['OW1', 'N', 'L', 'IY0']
# vowel
# nasal
# liquid
# vowel
# ['M', 'EY1', 'K', 'S']
# nasal
# vowel
# stop
# fricative
# ['M', 'AH1', 'D']
# nasal
# vowel
# stop
# ['R', 'EY1', 'Z', 'D']
# liquid
# vowel
# fricative
# stop
# ['ER0', 'AW1', 'N', 'D']
# vowel
# vowel
# nasal
# stop
# ['AH0']
# vowel
# ['D', 'IH1', 'R']
# stop
# vowel
# liquid
# Error ','
# ['AY1']
# vowel
# ['N', 'OW1']
# nasal
# vowel
# ['HH', 'AW1']
# aspirate
# vowel
# ['T', 'UW1']
# stop
# vowel
# ['CH', 'EY1', 'S']
# affricate
# vowel
# fricative
# ['B', 'AH1', 'K', 'S']
# stop
# vowel
# stop
# fricative
# ['B', 'EY1', 'B', 'IY0', 'S', 'IH2', 'T', 'ER0']
# stop
# vowel
# stop
# vowel
# fricative
# vowel
# stop
# vowel
# Error ','
# Error '16'
# Error ','
# ['T', 'AO1', 'T']
# stop
# vowel
# stop
# ['M', 'IY1']
# nasal
# vowel
# ['HH', 'AW1']
# aspirate
# vowel
# ['T', 'UW1']
# stop
# vowel
# ['M', 'EY1', 'K']
# nasal
# vowel
# stop
# ['F', 'AH1', 'K']
# fricative
# vowel
# stop
# ['AE1', 'T']
# vowel
# stop
# Error '7'
# Error ','
# ['AY1']
# vowel
# Error "'ve"
# ['B', 'IH1', 'N']
# stop
# vowel
# nasal
# ['R', 'EY1', 'Z', 'IH0', 'N']
# liquid
# vowel
# fricative
# vowel
# nasal
# Error "'"
# ['HH', 'EH1', 'L']
# aspirate
# vowel
# liquid
# Error ','
# ['S', 'OW1']
# fricative
# vowel
# ['AY1']
# vowel
# ['K', 'AE1', 'N']
# stop
# vowel
# nasal
# ['M', 'EY1', 'K']
# nasal
# vowel
# stop
# ['IH1', 'T']
# vowel
# stop
# ['T', 'UW1']
# stop
# vowel
# ['HH', 'EH1', 'V', 'AH0', 'N']
# aspirate
# vowel
# fricative
# vowel
# nasal
# ['P', 'IH1', 'K']
# stop
# vowel
# stop
# ['AH1', 'P']
# vowel
# stop
# ['AH0']
# vowel
# Error '2'
# ['L', 'IY1', 'T', 'ER0']
# liquid
# vowel
# stop
# vowel
# ['B', 'AH1', 'T']
# stop
# vowel
# stop
# ['AY1']
# vowel
# ['OW1', 'N', 'L', 'IY0']
# vowel
# nasal
# liquid
# vowel
# ['N', 'IY1', 'D']
# nasal
# vowel
# stop
# ['DH', 'AH0']
# fricative
# vowel
# ['P', 'L', 'AE1', 'S', 'T', 'IH0', 'K']
# stop
# liquid
# vowel
# fricative
# stop
# vowel
# stop
# ['N', 'OW1']
# nasal
# vowel
# ['HH', 'AW1']
# aspirate
# vowel
# ['T', 'UW1']
# stop
# vowel
# ['M', 'EY1', 'K']
# nasal
# vowel
# stop
# ['B', 'AA1', 'M', 'Z']
# stop
# vowel
# nasal
# fricative
# ['W', 'IH1', 'DH']
# semivowel
# vowel
# fricative
# ['AH0', 'L', 'UW1', 'M', 'AH0', 'N', 'AH0', 'M']
# vowel
# liquid
# vowel
# nasal
# vowel
# nasal
# vowel
# nasal
# ['AH0', 'N', 'D']
# vowel
# nasal
# stop
# ['AE1', 'S', 'AH0', 'D']
# vowel
# fricative
# vowel
# stop
# ['B', 'AH1', 'T', 'ER0', 'F', 'L', 'AY2']
# stop
# vowel
# stop
# vowel
# fricative
# liquid
# vowel
# ['IH0', 'F', 'EH1', 'K', 'T']
# vowel
# fricative
# vowel
# stop
# stop
# ['AH1', 'V']
# vowel
# fricative
# ['AH0']
# vowel
# ['HH', 'ER1', 'AH0', 'K', 'EY2', 'N']
# aspirate
# vowel
# vowel
# stop
# vowel
# nasal
# ['EH1', 'S']
# vowel
# fricative
# ['M', 'AE1', 'JH', 'IH0', 'K']
# nasal
# vowel
# affricate
# vowel
# stop
# Error ','
# ['T', 'AO0', 'R', 'N', 'EY1', 'D', 'OW2']
# stop
# vowel
# liquid
# nasal
# vowel
# stop
# vowel
# ['P', 'AE1', 'TH']
# stop
# vowel
# fricative
# ['IH0', 'N']
# vowel
# nasal
# ['DH', 'AH0']
# fricative
# vowel
# ['R', 'IH1', 'R']
# liquid
# vowel
# liquid
# ['V', 'Y', 'UW1']
# fricative
# semivowel
# vowel
# ['M', 'IH1', 'R', 'ER0']
# nasal
# vowel
# liquid
# vowel
# ['AH1', 'V']
# vowel
# fricative
# ['M', 'AY1']
# nasal
# vowel
# Error "'87"
# ['K', 'L', 'AE1', 'S', 'IH0', 'K']
# stop
# liquid
# vowel
# fricative
# vowel
# stop
# ['AY1']
# vowel
# ['AH0', 'M']
# vowel
# nasal
# ['T', 'AA1', 'K', 'AH0', 'N']
# stop
# vowel
# stop
# vowel
# nasal
# Error "'"
# ['AH0', 'B', 'AW1', 'T']
# vowel
# stop
# vowel
# stop
# ['G', 'AE1', 'D', 'Z', 'D', 'AH0', 'N']
# stop
# vowel
# stop
# fricative
# stop
# vowel
# nasal
# Error ','
# ['L', 'UH1', 'K']
# liquid
# vowel
# stop
# ['M', 'AA1', 'M', 'AH0']
# nasal
# vowel
# nasal
# vowel
# ['N', 'OW1']
# nasal
# vowel
# ['HH', 'AE1', 'N', 'D', 'Z']
# aspirate
# vowel
# nasal
# stop
# fricative
# Error ','
# ['AY1']
# vowel
# ['AH0', 'M']
# vowel
# nasal
# ['R', 'EY2', 'D', 'IY0', 'OW0', 'AE1', 'K', 'T', 'IH0', 'V']
# liquid
# vowel
# stop
# vowel
# vowel
# vowel
# stop
# stop
# vowel
# fricative
# Error is 92
# ['liquid',
#  'vowel',
#  'stop',
#  'vowel',
#  'stop',
#  'fricative',
#  'vowel',
#  'semivowel',
#  'vowel',
#  'nasal',
#  'vowel',
#  'stop',
#  'vowel',
#  'stop',
#  'fricative',
#  'stop',
#  'vowel',
#  'stop',
#  'fricative',
#  'vowel',
#  'liquid',
#  'nasal',
#  'vowel',
#  'aspirate',
#  'vowel',
#  'fricative',
#  'vowel',
#  'fricative',
#  'vowel',
#  'stop',
#  'vowel',
#  'semivowel',
#  'vowel',
#  'liquid',
#  'nasal',
#  'vowel',
#  'nasal',
#  'fricative',
#  'liquid',
#  'vowel',
#  'nasal',
#  'vowel',
#  'stop',
#  'liquid',
#  'vowel',
#  'vowel',
#  'stop',
#  'vowel',
#  'nasal',
#  'fricative',
#  'aspirate',
#  'vowel',
#  'fricative',
#  'stop',
#  'vowel',
#  'nasal',
#  'liquid',
#  'vowel',
#  'nasal',
#  'affricate',
#  'stop',
#  'fricative',
#  'liquid',
#  'vowel',
#  'nasal',
#  'nasal',
#  'vowel',
#  'liquid',
#  'fricative',
#  'stop',
#  'vowel',
#  'liquid',
#  'vowel',
#  'vowel',
#  'vowel',
#  'nasal',
#  'stop',
#  'semivowel',
#  'vowel',
#  'liquid',
#  'aspirate',
#  'vowel',
#  'stop',
#  'vowel',
#  'liquid',
#  'liquid',
#  'vowel',
#  'nasal',
#  'stop',
#  'vowel',
#  'fricative',
#  'liquid',
#  'vowel',
#  'liquid',
#  'vowel',
#  'stop',
#  'vowel',
#  'liquid',
#  'vowel',
#  'fricative',
#  'fricative',
#  'vowel',
#  'stop',
#  'vowel',
#  'fricative',
#  'nasal',
#  'vowel',
#  'fricative',
#  'vowel',
#  'stop',
#  'vowel',
#  'vowel',
#  'nasal',
#  'stop',
#  'nasal',
#  'vowel',
#  'semivowel',
#  'vowel',
#  'liquid',
#  'stop',
#  'fricative',
#  'vowel',
#  'stop',
#  'vowel',
#  'nasal',
#  'vowel',
#  'semivowel',
#  'vowel',
#  'liquid',
#  'stop',
#  'fricative',
#  'vowel',
#  'fricative',
#  'semivowel',
#  'vowel',
#  'liquid',
#  'vowel',
#  'stop',
#  'fricative',
#  'stop',
#  'vowel',
#  'liquid',
#  'vowel',
#  'stop',
#  'vowel',
#  'stop',
#  'liquid',
#  'vowel',
#  'stop',
#  'vowel',
#  'nasal',
#  'vowel',
#  'fricative',
#  'stop',
#  'vowel',
#  'nasal',
#  'fricative',
#  'stop',
#  'vowel',
#  'nasal',
#  'stop',
#  'vowel',
#  'stop',
#  'stop',
#  'vowel',
#  'nasal',
#  'stop',
#  'liquid',
#  'vowel',
#  'fricative',
#  'stop',
#  'vowel',
#  'stop',
#  'stop',
#  'vowel',
#  'vowel',
#  'nasal',
#  'vowel',
#  'nasal',
#  'stop',
#  'vowel',
#  'stop',
#  'liquid',
#  'vowel',
#  'nasal',
#  'stop',
#  'fricative',
#  'vowel',
#  'liquid',
#  'stop',
#  'vowel',
#  'vowel',
#  'liquid',
#  'vowel',
#  'fricative',
#  'vowel',
#  'liquid',
#  'vowel',
#  'stop',
#  'fricative',
#  'vowel',
#  'liquid',
#  'stop',
#  'vowel',
#  'vowel',
#  'nasal',
#  'vowel',
#  'stop',
#  'vowel',
#  'vowel',
#  'stop',
#  'liquid',
#  'vowel',
#  'semivowel',
#  'vowel',
#  'nasal',
#  'fricative',
#  'vowel',
#  'stop',
#  'vowel',
#  'nasal',
#  'fricative',
#  'liquid',
#  'vowel',
#  'nasal',
#  'vowel',
#  'stop',
#  'liquid',
#  'vowel',
#  'vowel',
#  'stop',
#  'vowel',
#  'nasal',
#  'fricative',
#  'aspirate',
#  'vowel',
#  'fricative',
#  'stop',
#  'vowel',
#  'nasal',
#  'liquid',
#  'vowel',
#  'nasal',
#  'affricate',
#  'stop',
#  'fricative',
#  'liquid',
#  'vowel',
#  'nasal',
#  'nasal',
#  'vowel',
#  'liquid',
#  'fricative',
#  'stop',
#  'vowel',
#  'liquid',
#  'vowel',
#  'vowel',
#  'vowel',
#  'nasal',
#  'stop',
#  'semivowel',
#  'vowel',
#  'liquid',
#  'aspirate',
#  'vowel',
#  'stop',
#  'vowel',
#  'liquid',
#  'liquid',
#  'vowel',
#  'nasal',
#  'stop',
#  'vowel',
#  'fricative',
#  'liquid',
#  'vowel',
#  'liquid',
#  'vowel',
#  'stop',
#  'vowel',
#  'liquid',
#  'vowel',
#  'fricative',
#  'fricative',
#  'vowel',
#  'stop',
#  'vowel',
#  'fricative',
#  'nasal',
#  'vowel',
#  'fricative',
#  'vowel',
#  'stop',
#  'vowel',
#  'vowel',
#  'nasal',
#  'stop',
#  'nasal',
#  'vowel',
#  'semivowel',
#  'vowel',
#  'liquid',
#  'stop',
#  'fricative',
#  'vowel',
#  'stop',
#  'vowel',
#  'nasal',
#  'vowel',
#  'semivowel',
#  'vowel',
#  'liquid',
#  'stop',
#  'fricative',
#  'vowel',
#  'fricative',
#  'semivowel',
#  'vowel',
#  'liquid',
#  'nasal',
#  'vowel',
#  'nasal',
#  'semivowel',
#  'vowel',
#  'liquid',
#  'vowel',
#  'stop',
#  'fricative',
#  'stop',
#  'vowel',
#  'liquid',
#  'vowel',
#  'stop',
#  'vowel',
#  'stop',
#  'liquid',
#  'vowel',
#  'stop',
#  'vowel',
#  'nasal',
#  'vowel',
#  'fricative',
#  'stop',
#  'vowel',
#  'nasal',
#  'fricative',
#  'stop',
#  'vowel',
#  'nasal',
#  'stop',
#  'vowel',
#  'stop',
#  'stop',
#  'vowel',
#  'nasal',
#  'vowel',
#  'vowel',
#  'nasal',
#  'vowel',
#  'vowel',
#  'nasal',
#  'fricative',
#  'vowel',
#  'vowel',
#  'nasal',
#  'vowel',
#  'liquid',
#  'vowel',
#  'stop',
#  'vowel',
#  'nasal',
#  'vowel',
#  'stop',
#  'vowel',
#  'liquid',
#  'vowel',
#  'fricative',
#  'vowel',
#  'fricative',
#  'vowel',
#  'fricative',
#  'stop',
#  'vowel',
#  'liquid',
#  'vowel',
#  'liquid',
#  'vowel',
#  'stop',
#  'aspirate',
#  'vowel',
#  'nasal',
#  'stop',
#  'stop',
#  'liquid',
#  'vowel',
#  'nasal',
#  'affricate',
#  'liquid',
#  'vowel',
#  'fricative',
#  'stop',
#  'aspirate',
#  'vowel',
#  'nasal',
#  'stop',
#  'vowel',
#  'liquid',
#  'vowel',
#  'affricate',
#  'vowel',
#  'fricative',
#  'vowel',
#  'nasal',
#  'vowel',
#  'stop',
#  'vowel',
#  'liquid',
#  'vowel',
#  'vowel',
#  'nasal',
#  'vowel',
#  'nasal',
#  'vowel',
#  'nasal',
#  'stop',
#  'vowel',
#  'liquid',
#  'vowel',
#  'semivowel',
#  'vowel',
#  'stop',
#  'stop',
#  'liquid',
#  'vowel',
#  'fricative',
#  'aspirate',
#  'vowel',
#  'liquid',
#  'stop',
#  'fricative',
#  'liquid',
#  'vowel',
#  'stop',
#  'nasal',
#  'vowel',
#  'liquid',
#  'vowel',
#  'semivowel',
#  'vowel',
#  'liquid',
#  'vowel',
#  'aspirate',
#  'vowel',
#  'liquid',
#  'stop',
#  'liquid',
#  'vowel',
#  'stop',
#  'vowel',
#  'stop',
#  'vowel',
#  'stop',
#  'vowel',
#  'nasal',
#  'nasal',
#  'vowel',
#  'liquid',
#  'vowel',
#  'fricative',
#  'vowel',
#  'liquid',
#  'vowel',
#  'vowel',
#  'nasal',
#  'aspirate',
#  'vowel',
#  'stop',
#  'vowel',
#  'fricative',
#  'vowel',
#  'nasal',
#  'fricative',
#  'vowel',
#  'stop',
#  'vowel',
#  'stop',
#  'vowel',
#  'nasal',
#  'fricative',
#  'vowel',
#  'stop',
#  'vowel',
#  'fricative',
#  'vowel',
#  'stop',
#  'vowel',
#  'stop',
#  'vowel',
#  'liquid',
#  'fricative',
#  'vowel',
#  'fricative',
#  'liquid',
#  'vowel',
#  'vowel',
#  'nasal',
#  'vowel',
#  'nasal',
#  'stop',
#  'vowel',
#  'nasal',
#  'vowel',
#  'stop',
#  'nasal',
#  'vowel',
#  'vowel',
#  'stop',
#  'vowel',
#  'stop',
#  'aspirate',
#  'vowel',
#  'stop',
#  'semivowel',
#  'vowel',
#  'fricative',
#  'vowel',
#  'stop',
#  'vowel',
#  'stop',
#  'vowel',
#  'liquid',
#  'fricative',
#  'vowel',
#  'fricative',
#  'vowel',
#  'nasal',
#  'stop',
#  'nasal',
#  'vowel',
#  'stop',
#  'vowel',
#  'aspirate',
#  'vowel',
#  'liquid',
#  'vowel',
#  'nasal',
#  'stop',
#  'vowel',
#  'fricative',
#  'vowel',
#  'stop',
#  'vowel',
#  'nasal',
#  'fricative',
#  'vowel',
#  'stop',
#  'vowel',
#  'fricative',
#  'vowel',
#  'liquid',
#  'stop',
#  'liquid',
#  'vowel',
#  'stop',
#  'vowel',
#  'stop',
#  'vowel',
#  'liquid',
#  'vowel',
#  'nasal',
#  'vowel',
#  'affricate',
#  'vowel',
#  'fricative',
#  'vowel',
#  'stop',
#  'vowel',
#  'stop',
#  'fricative',
#  'stop',
#  'vowel',
#  'stop',
#  'vowel',
#  'semivowel',
#  'vowel',
#  'stop',
#  'vowel',
#  'stop',
#  'vowel',
#  'liquid',
#  'vowel',
#  'nasal',
#  'stop',
#  'fricative',
#  'vowel',
#  'stop',
#  'vowel',
#  'fricative',
#  'vowel',
#  'stop',
#  'vowel',
#  'stop',
#  'aspirate',
#  'vowel',
#  'liquid',
#  'stop',
#  'vowel',
#  'affricate',
#  'stop',
#  'liquid',
#  'vowel',
#  'nasal',
#  'vowel',
#  'liquid',
#  'vowel',
#  'nasal',
#  'fricative',
#  'vowel',
#  'fricative',
#  'vowel',
#  'liquid',
#  'liquid',
#  'vowel',
#  'nasal',
#  'stop',
#  'vowel',
#  'nasal',
#  'vowel',
#  'vowel',
#  'nasal',
#  'stop',
#  'liquid',
#  'vowel',
#  'nasal',
#  'vowel',
#  'stop',
#  'vowel',
#  'nasal',
#  'stop',
#  'vowel',
#  'vowel',
#  'nasal',
#  'stop',
#  'vowel',
#  'nasal',
#  'stop',
#  'vowel',
#  'stop',
#  'semivowel',
#  'vowel',
#  'stop',
#  'vowel',
#  'stop',
#  'vowel',
#  'stop',
#  'liquid',
#  'vowel',
#  'nasal',
#  'liquid',
#  'vowel',
#  'stop',
#  'vowel',
#  'stop',
#  'vowel',
#  'stop',
#  'vowel',
#  'fricative',
#  'semivowel',
#  'vowel',
#  'semivowel',
#  'vowel',
#  'nasal',
#  'stop',
#  'vowel',
#  'stop',
#  'liquid',
#  'vowel',
#  'stop',
#  'fricative',
#  'vowel',
#  'nasal',
#  'aspirate',
#  'vowel',
#  'nasal',
#  'fricative',
#  'fricative',
#  'vowel',
#  'stop',
#  'semivowel',
#  'vowel',
#  'fricative',
#  'vowel',
#  'stop',
#  'semivowel',
#  'vowel',
#  'stop',
#  'vowel',
#  'liquid',
#  'semivowel',
#  'vowel',
#  'stop',
#  'vowel',
#  'stop',
#  'vowel',
#  'stop',
#  'vowel',
#  'fricative',
#  'vowel',
#  'stop',
#  'semivowel',
#  'vowel',
#  'vowel',
#  'vowel',
#  'nasal',
#  'vowel',
#  'fricative',
#  'vowel',
#  'stop',
#  'vowel',
#  'fricative',
#  'liquid',
#  'vowel',
#  'stop',
#  'vowel',
#  'stop',
#  'vowel',
#  'stop',
#  'fricative',
#  'vowel',
#  'nasal',
#  'vowel',
#  'nasal',
#  'vowel',
#  'stop',
#  'vowel',
#  'stop',
#  'vowel',
#  'vowel',
#  'nasal',
#  'stop',
#  'vowel',
#  'fricative',
#  'vowel',
#  'fricative',
#  'vowel',
#  'stop',
#  'vowel',
#  'nasal',
#  'fricative',
#  'vowel',
#  'liquid',
#  'fricative',
#  'vowel',
#  'vowel',
#  'nasal',
#  'stop',
#  'vowel',
#  'liquid',
#  'fricative',
#  'vowel',
#  'nasal',
#  'stop',
#  'liquid',
#  'vowel',
#  'fricative',
#  'stop',
#  'vowel',
#  'stop',
#  'vowel',
#  'nasal',
#  'fricative',
#  'vowel',
#  'liquid',
#  'fricative',
#  'vowel',
#  'stop',
#  'vowel',
#  'nasal',
#  'affricate',
#  'vowel',
#  'vowel',
#  'fricative',
#  'fricative',
#  'vowel',
#  'stop',
#  'vowel',
#  'stop',
#  'liquid',
#  'vowel',
#  'nasal',
#  'stop',
#  'stop',
#  'vowel',
#  'stop',
#  'vowel',
#  'nasal',
#  'vowel',
#  'nasal',
#  'stop',
#  'fricative',
#  'vowel',
#  'liquid',
#  'fricative',
#  'vowel',
#  'aspirate',
#  'vowel',
#  'stop',
#  'fricative',
#  'fricative',
#  'vowel',
#  'stop',
#  'vowel',
#  'nasal',
#  'vowel',
#  'fricative',
#  'vowel',
#  'affricate',
#  'vowel',
#  'nasal',
#  'fricative',
#  'vowel',
#  'stop',
#  'vowel',
#  'stop',
#  'liquid',
#  'vowel',
#  'stop',
#  'fricative',
#  'liquid',
#  'vowel',
#  'nasal',
#  'fricative',
#  'liquid',
#  'vowel',
#  'nasal',
#  'fricative',
#  'vowel',
#  'stop',
#  'vowel',
#  'nasal',
#  'vowel',
#  'fricative',
#  'vowel',
#  'stop',
#  'liquid',
#  'vowel',
#  'stop',
#  'vowel',
#  'stop',
#  'stop',
#  'vowel',
#  'stop',
#  'stop',
#  'vowel',
#  'fricative',
#  'vowel',
#  'semivowel',
#  'vowel',
#  'nasal',
#  'vowel',
#  'nasal',
#  'fricative',
#  'vowel',
#  'semivowel',
#  'vowel',
#  'stop',
#  'vowel',
#  'stop',
#  'vowel',
#  'stop',
#  'vowel',
#  'nasal',
#  'semivowel',
#  'vowel',
#  'stop',
#  'vowel',
#  'stop',
#  'vowel',
#  'nasal',
#  'stop',
#  'vowel',
#  'stop',
#  'vowel',
#  'stop',
#  'fricative',
#  'vowel',
#  'affricate',
#  'vowel',
#  'nasal',
#  'fricative',
#  'fricative',
#  'vowel',
#  'liquid',
#  'fricative',
#  'vowel',
#  'affricate',
#  'vowel',
#  'nasal',
#  'affricate',
#  'vowel',
#  'stop',
#  'vowel',
#  'fricative',
#  'vowel',
#  'stop',
#  'semivowel',
#  'vowel',
#  'liquid',
#  'stop',
#  'vowel',
#  'fricative',
#  'vowel',
#  'liquid',
#  'semivowel',
#  'vowel',
#  'liquid',
#  'fricative',
#  'vowel',
#  'stop',
#  'vowel',
#  'stop',
#  'liquid',
#  'vowel',
#  'fricative',
#  'vowel',
#  'vowel',
#  'stop',
#  'fricative',
#  'vowel',
#  'stop',
#  'vowel',
#  'nasal',
#  'stop',
#  'liquid',
#  'vowel',
#  'stop',
#  'semivowel',
#  'vowel',
#  'fricative',
#  'vowel',
#  'nasal',
#  'vowel',
#  'stop',
#  'vowel',
#  'stop',
#  'liquid',
#  'vowel',
#  'fricative',
#  'vowel',
#  'vowel',
#  'stop',
#  'fricative',
#  'vowel',
#  'stop',
#  'vowel',
#  'nasal',
#  'fricative',
#  'stop',
#  'vowel',
#  'stop',
#  'vowel',
#  'fricative',
#  'vowel',
#  'nasal',
#  'vowel',
#  'liquid',
#  'vowel',
#  'fricative',
#  'vowel',
#  'vowel',
#  'stop',
#  'fricative',
#  'vowel',
#  'stop',
#  'liquid',
#  'vowel',
#  'semivowel',
#  'vowel',
#  'nasal',
#  'vowel',
#  'liquid',
#  'vowel',
#  'fricative',
#  'vowel',
#  'stop',
#  'vowel',
#  'affricate',
#  'vowel',
#  'nasal',
#  'liquid',
#  'vowel',
#  'vowel',
#  'nasal',
#  'fricative',
#  'stop',
#  'vowel',
#  'vowel',
#  'affricate',
#  'aspirate',
#  ...]

# %%
def make_sim_matrix(phonemes_list):
    sim_matrix = [[]]
    for p in phonemes:
        index = phonemes.get_loc[p]
        if (index > 3) and (index < (len(phonemes) - 3)):
            sim_matrix[index, index - 3] = phoneme_similarity(phonemes[index], phonemes[index - 3])
            sim_matrix[index, index - 2] = phoneme_similarity(phonemes[index], phonemes[index - 2])
            sim_matrix[index, index - 1] = phoneme_similarity(phonemes[index], phonemes[index - 1])
            sim_matrix[index, index] = phoneme_similarity(phonemes[index], phonemes[index])
            sim_matrix[index, index + 1] = phoneme_similarity(phonemes[index], phonemes[index + 1])
            sim_matrix[index, index + 2] = phoneme_similarity(phonemes[index], phonemes[index + 2])
            sim_matrix[index, index + 3] = phoneme_similarity(phonemes[index], phonemes[index + 3])

        elif (index == 1):
            sim_matrix[index, index] = phoneme_similarity(phonemes[index], phonemes[index])
            sim_matrix[index, index + 1] = phoneme_similarity(phonemes[index], phonemes[index + 1])
            sim_matrix[index, index + 2] = phoneme_similarity(phonemes[index], phonemes[index + 2])
            sim_matrix[index, index + 3] = phoneme_similarity(phonemes[index], phonemes[index + 3])
        
        elif (index == 2):
            sim_matrix[index, index - 1] = phoneme_similarity(phonemes[index], phonemes[index - 1])
            sim_matrix[index, index] = phoneme_similarity(phonemes[index], phonemes[index])
            sim_matrix[index, index + 1] = phoneme_similarity(phonemes[index], phonemes[index + 1])
            sim_matrix[index, index + 2] = phoneme_similarity(phonemes[index], phonemes[index + 2])
            sim_matrix[index, index + 3] = phoneme_similarity(phonemes[index], phonemes[index + 3])
        
        elif (index == 3):
            sim_matrix[index, index - 2] = phoneme_similarity(phonemes[index], phonemes[index - 2])
            sim_matrix[index, index - 1] = phoneme_similarity(phonemes[index], phonemes[index - 1])
            sim_matrix[index, index] = phoneme_similarity(phonemes[index], phonemes[index])
            sim_matrix[index, index + 1] = phoneme_similarity(phonemes[index], phonemes[index + 1])
            sim_matrix[index, index + 2] = phoneme_similarity(phonemes[index], phonemes[index + 2])
            sim_matrix[index, index + 3] = phoneme_similarity(phonemes[index], phonemes[index + 3])

        elif (index == len(phonmes) - 3):
            sim_matrix[index, index - 3] = phoneme_similarity(phonemes[index], phonemes[index - 3])
            sim_matrix[index, index - 2] = phoneme_similarity(phonemes[index], phonemes[index - 2])
            sim_matrix[index, index - 1] = phoneme_similarity(phonemes[index], phonemes[index - 1])
            sim_matrix[index, index] = phoneme_similarity(phonemes[index], phonemes[index])
            sim_matrix[index, index + 1] = phoneme_similarity(phonemes[index], phonemes[index + 1])
            sim_matrix[index, index + 2] = phoneme_similarity(phonemes[index], phonemes[index + 2])
    

        elif (index == len(phonmes) - 2):
            sim_matrix[index, index - 3] = phoneme_similarity(phonemes[index], phonemes[index - 3])
            sim_matrix[index, index - 2] = phoneme_similarity(phonemes[index], phonemes[index - 2])
            sim_matrix[index, index - 1] = phoneme_similarity(phonemes[index], phonemes[index - 1])
            sim_matrix[index, index] = phoneme_similarity(phonemes[index], phonemes[index])
            sim_matrix[index, index + 1] = phoneme_similarity(phonemes[index], phonemes[index + 1])
        

        elif (index == len(phonmes) - 1):
            sim_matrix[index, index - 3] = phoneme_similarity(phonemes[index], phonemes[index - 3])
            sim_matrix[index, index - 2] = phoneme_similarity(phonemes[index], phonemes[index - 2])
            sim_matrix[index, index - 1] = phoneme_similarity(phonemes[index], phonemes[index - 1])
            sim_matrix[index, index] = phoneme_similarity(phonemes[index], phonemes[index])
    
            
        return sim_matrix

# %%
def phoneme_similarity(p, p1):
    
    # What type of sounds is the phononeme
    p = nltk.sound_type(p)
    p1 = nltk.sound_type(p)
    
    # Note that phoneme_similarity(p, p1) == phoneme_similarity(p1, p)
    # That is phoneme_similarity is symmetric
    
    if p == p1:
        sim = 1
        
    elif p == 'fricative':
        if p1 == 'affricate':
            sim = 
        if p1 == 'vowel':
            sim = 
        if p1 == 'semivowel':
            sim = 
        if p1 == 'nasal':
            sim = 
        if p1 == 'liquid':
            sim = 
        if p1 == 'aspirate':
            sim
        if p1 == 'stop':
            sim = 
            
    elif p == 'affricate':
        if p1 == 'vowel':
            sim = 
        if p1 == 'semivowel':
            sim = 
        if p1 == 'nasal':
            sim = 
        if p1 == 'liquid':
            sim = 
        if p1 == 'aspirate':
            sim
        if p1 == 'stop':
            sim = 

            
    elif p == 'vowel':
        if p1 == 'semivowel':
            sim = 
        if p1 == 'nasal':
            sim = 
        if p1 == 'liquid':
            sim = 
        if p1 == 'aspirate':
            sim
        if p1 == 'stop':
            sim = 
            
    elif p == 'semivowel':
        if p1 == 'nasal':
            sim = 
        if p1 == 'liquid':
            sim = 
        if p1 == 'aspirate':
            sim
        if p1 == 'stop':
            sim = 
            
    elif p == 'nasal':
        if p1 == 'liquid':
            sim = 
        if p1 == 'aspirate':
            sim
        if p1 == 'stop':
            sim = 
            
    elif p == 'liquid':
        if p1 == 'aspirate':
            sim
        if p1 == 'stop':
            sim = 
            
    elif p == 'aspirate':
        if p1 == 'stop':
            sim = 
    
        
        
    return sim
# Out:
#   File "<ipython-input-9-e3c30627b820>", line 15
#     sim =
#           ^
# SyntaxError: invalid syntax

# %%
#def phoneme_similarity(p, p1):
    
    # What type of sounds is the phononeme
    p = nltk.sound_type(p)
    p1 = nltk.sound_type(p)
    
    if p == p1:
        sim = 1
        
    elif p == 'fricative':
        if p1 == 'affricate':
            sim = 
        if p1 == 'vowel':
            sim = 
        if p1 == 'semivowel':
            sim = 
        if p1 == 'nasal':
            sim = 
        if p1 == 'liquid':
            sim = 
        if p1 == 'aspirate':
            sim
        if p1 == 'stop':
            sim = 
            
    elif p == 'affricate':
        if p1 == 'fricative':
            sim = 
        if p1 == 'vowel':
            sim = 
        if p1 == 'semivowel':
            sim = 
        if p1 == 'nasal':
            sim = 
        if p1 == 'liquid':
            sim = 
        if p1 == 'aspirate':
            sim
        if p1 == 'stop':
            sim = 

            
    elif p == 'vowel':
        if p1 == 'fricative':
            sim = 
        if p1 == 'affricate':
            sim = 
        if p1 == 'semivowel':
            sim = 
        if p1 == 'nasal':
            sim = 
        if p1 == 'liquid':
            sim = 
        if p1 == 'aspirate':
            sim
        if p1 == 'stop':
            sim = 
            
    elif p == 'semivowel':
        if p1 == 'fricative':
            sim = 
        if p1 == 'affricate':
            sim = 
        if p1 == 'vowel':
            sim = 
        if p1 == 'nasal':
            sim = 
        if p1 == 'liquid':
            sim = 
        if p1 == 'aspirate':
            sim
        if p1 == 'stop':
            sim = 
            
    elif p == 'nasal':
        if p1 == 'fricative':
            sim = 
        if p1 == 'affricate':
            sim = 
        if p1 == 'vowel':
            sim = 
        if p1 == 'semivowel':
            sim = 
        if p1 == 'liquid':
            sim = 
        if p1 == 'aspirate':
            sim
        if p1 == 'stop':
            sim = 
            
    elif p == 'liquid':
        if p1 == 'fricative':
            sim = 
        if p1 == 'affricate':
            sim = 
        if p1 == 'vowel':
            sim = 
        if p1 == 'semivowel':
            sim = 
        if p1 == 'nasal':
            sim = 
        if p1 == 'aspirate':
            sim
        if p1 == 'stop':
            sim = 
            
    elif p == 'aspirate':
        if p1 == 'fricative':
            sim = 
        if p1 == 'affricate':
            sim = 
        if p1 == 'vowel':
            sim = 
        if p1 == 'semivowel':
            sim = 
        if p1 == 'nasal':
            sim = 
        if p1 == 'liquid':
            sim = 
        if p1 == 'stop':
            sim = 
            
    elif p == 'stop':
        if p1 == 'fricative':
            sim = 
        if p1 == 'affricate':
            sim = 
        if p1 == 'vowel':
            sim = 
        if p1 == 'semivowel':
            sim = 
        if p1 == 'nasal':
            sim = 
        if p1 == 'liquid':
            sim = 
        if p1 == 'aspirate':
            sim
    
        
        
    return sim
# Out:
#   File "<ipython-input-10-5501ab68f4f2>", line 4
#     p = nltk.sound_type(p)
#     ^
# IndentationError: unexpected indent
